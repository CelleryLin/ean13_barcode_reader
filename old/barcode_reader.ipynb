# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import image_proc as ip

# %load_ext autoreload
# %autoreload 2

# %%
img = cv2.imread("./test2.bmp")
img = cv2.resize(img, (300, 400))
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
img = ip.normalize(img)

# contrast enhancement
# img = ip.contrast(img,0)

# detect barcode
_, label, location = ip.barcode_detection(img, dilate_size=9, erode_size=7, morph_iter=4)
# binarization
# img = ip.binarize(img, 0.2)

plt.figure(figsize=(20,10))
plt.subplot(1,2,1)
plt.imshow(img, cmap="gray")
plt.subplot(1,2,2)
plt.imshow(label*img, cmap="gray")
print(location)
plt.plot(location)
plt.show()
# Out:
# Applying sobel filter...
# Applying morphing...
# 100%|██████████| 4/4 [00:01<00:00,  2.49it/s]
# Detecting objects...
# Making bounding box...
# (152.5401148663574, 223.77866136514248)

# %%
# fft2d to image
img = cv2.imread("./test1.bmp")
img = cv2.resize(img, (300, 400))
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

img = ip.normalize(img)
img_fft = np.fft.fft2(img)
img_fft = np.fft.fftshift(img_fft)
img_fft = np.abs(img_fft)
img_fft = np.log(img_fft)
img_fft = ip.normalize(img_fft)

plt.figure(figsize=(20,10))
plt.subplot(1,2,1)
plt.imshow(img, cmap="gray")
plt.subplot(1,2,2)
plt.imshow(img_fft, cmap="gray")
plt.show()
